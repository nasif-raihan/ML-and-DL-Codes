# %% [markdown]
# <a href="https://colab.research.google.com/github/nasif-raihan/ML-and-DL-Codes/blob/main/handling_date_%26_time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/main/day34-handling-date-and-time/messages.csv'
df = pd.read_csv(url)
df.sample(5)
# Out:
#                     date                                                msg
# 209  2012-08-02 00:13:00    Аня+Саша. И поставь пожалуста 018 спасибо. :-).
# 503  2013-07-13 23:48:00  симпатичный П30 ищет и/о сейчас на Кирова06343...
# 822  2015-07-21 00:02:00  ТОЛЬКО ЗАПОРОЖЬЕ Встречусь с девушкой без комп...
# 434  2014-07-28 00:28:00              ВСТРЕЧЮСЬ С ДЕВУШКОЙ СЕЙЧАС Я НА АВТО
# 788  2012-09-13 00:27:00  парень 33 приг стр  дев/ж за *** в гости 8063 ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
df['date'] = pd.to_datetime(df['date'])
df.sample(2)
# Out:
#                    date                              msg
# 38  2013-10-26 00:12:00  сделаю инт массаж М за 40 Света
# 401 2013-09-11 01:36:00      Катюша  люблю тебя безумно!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
df.drop(['msg'], axis=1, inplace=True)

# %%
df['yr'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['hr'] = df['date'].dt.hour
df['min'] = df['date'].dt.minute
df['sec'] = df['date'].dt.second
df['month_name'] = df['date'].dt.month_name()
df['day'] = df['date'].dt.day
df['day_of_week'] = df['date'].dt.dayofweek
df['day_name'] = df['date'].dt.day_name()
df['weekday'] = df['date'].dt.weekday
df['quarter'] = df['date'].dt.quarter

df.head(2)
# Out:
#                  date    yr  month  hr  min  sec month_name  day  day_of_week  \
# 0 2013-12-15 00:50:00  2013     12   0   50    0   December   15            6
# 1 2014-04-29 23:40:00  2014      4  23   40    0      April   29            1
#
#   day_name  weekday  quarter
# 0   Sunday        6        4
# 1  Tuesday        1        2
